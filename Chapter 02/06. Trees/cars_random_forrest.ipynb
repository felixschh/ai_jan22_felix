# %%
car_data = 'https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data'
# names = 'https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.names'

# %%
import pandas as pd

pd.read_csv(car_data, header=None)
# Out:
#           0      1      2     3      4     5      6
# 0     vhigh  vhigh      2     2  small   low  unacc
# 1     vhigh  vhigh      2     2  small   med  unacc
# 2     vhigh  vhigh      2     2  small  high  unacc
# 3     vhigh  vhigh      2     2    med   low  unacc
# 4     vhigh  vhigh      2     2    med   med  unacc
# ...     ...    ...    ...   ...    ...   ...    ...
# 1723    low    low  5more  more    med   med   good
# 1724    low    low  5more  more    med  high  vgood
# 1725    low    low  5more  more    big   low  unacc
# 1726    low    low  5more  more    big   med   good
# 1727    low    low  5more  more    big  high  vgood
#
# [1728 rows x 7 columns]

# %%
columns = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']

# %%
df = pd.read_csv(car_data, names = columns)
df
# Out:
#      buying  maint  doors persons lug_boot safety acceptability
# 0     vhigh  vhigh      2       2    small    low         unacc
# 1     vhigh  vhigh      2       2    small    med         unacc
# 2     vhigh  vhigh      2       2    small   high         unacc
# 3     vhigh  vhigh      2       2      med    low         unacc
# 4     vhigh  vhigh      2       2      med    med         unacc
# ...     ...    ...    ...     ...      ...    ...           ...
# 1723    low    low  5more    more      med    med          good
# 1724    low    low  5more    more      med   high         vgood
# 1725    low    low  5more    more      big    low         unacc
# 1726    low    low  5more    more      big    med          good
# 1727    low    low  5more    more      big   high         vgood
#
# [1728 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
for col_name in df.columns:
    plt.figure()
    plt.hist(df[col_name])
    plt.title(col_name)

# %%
df = pd.read_csv(car_data, names=columns)
df = df.replace({'5more': 5, 'more': 5})
df = df.replace({'vhigh': 4, 'high': 3, 'med': 2, 'low': 1})
df = df.replace({'big': 3, 'small': 1})
df = df.replace({'acc': 1, 'unacc': 0, 'good': 2, 'vgood': 3})
df
# Out:
#       buying  maint doors persons  lug_boot  safety  acceptability
# 0          4      4     2       2         1       1              0
# 1          4      4     2       2         1       2              0
# 2          4      4     2       2         1       3              0
# 3          4      4     2       2         2       1              0
# 4          4      4     2       2         2       2              0
# ...      ...    ...   ...     ...       ...     ...            ...
# 1723       1      1     5       5         2       2              2
# 1724       1      1     5       5         2       3              3
# 1725       1      1     5       5         3       1              0
# 1726       1      1     5       5         3       2              2
# 1727       1      1     5       5         3       3              3
#
# [1728 rows x 7 columns]

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
y.unique()
# Out:
# array([0, 1, 3, 2])

# %%
df = pd.read_csv(car_data, names=columns)
df = df.replace({'5more': 5, 'more': 5})
df = df.replace({'vhigh': 4, 'high': 3, 'med': 2, 'low': 1})
df = df.replace({'big': 3, 'small': 1})
df = df.replace({'acc': 1, 'unacc': 0, 'good': 2, 'vgood': 3})
df
# Out:
#       buying  maint doors persons  lug_boot  safety  acceptability
# 0          4      4     2       2         1       1              0
# 1          4      4     2       2         1       2              0
# 2          4      4     2       2         1       3              0
# 3          4      4     2       2         2       1              0
# 4          4      4     2       2         2       2              0
# ...      ...    ...   ...     ...       ...     ...            ...
# 1723       1      1     5       5         2       2              2
# 1724       1      1     5       5         2       3              3
# 1725       1      1     5       5         3       1              0
# 1726       1      1     5       5         3       2              2
# 1727       1      1     5       5         3       3              3
#
# [1728 rows x 7 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf = dt_clf.fit(X_train, y_train)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(15, 15))
plot_tree(dt_clf,
          filled=True,
          rounded=True,
          class_names=['unacc', 'acc', 'good', 'vgood'],
         feature_names=X.columns)
# Out:
# [Text(0.5960365853658537, 0.9615384615384616, 'safety <= 1.5\ngini = 0.452\nsamples = 1209\nvalue = [852, 266, 50, 41]\nclass = unacc'),
#  Text(0.5838414634146342, 0.8846153846153846, 'gini = 0.0\nsamples = 407\nvalue = [407, 0, 0, 0]\nclass = unacc'),
#  Text(0.6082317073170732, 0.8846153846153846, 'persons <= 3.0\ngini = 0.576\nsamples = 802\nvalue = [445, 266, 50, 41]\nclass = unacc'),
#  Text(0.5960365853658537, 0.8076923076923077, 'gini = 0.0\nsamples = 260\nvalue = [260, 0, 0, 0]\nclass = unacc'),
#  Text(0.6204268292682927, 0.8076923076923077, 'buying <= 2.5\ngini = 0.628\nsamples = 542\nvalue = [185, 266, 50, 41]\nclass = acc'),
#  Text(0.3201219512195122, 0.7307692307692307, 'maint <= 1.5\ngini = 0.646\nsamples = 264\nvalue = [34, 139, 50, 41]\nclass = acc'),
#  Text(0.11280487804878049, 0.6538461538461539, 'safety <= 2.5\ngini = 0.612\nsamples = 65\nvalue = [3, 9, 35, 18]\nclass = good'),
#  Text(0.06097560975609756, 0.5769230769230769, 'lug_boot <= 1.5\ngini = 0.456\nsamples = 31\nvalue = [1, 9, 21, 0]\nclass = good'),
#  Text(0.036585365853658534, 0.5, 'doors <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0, 0]\nclass = acc'),
#  Text(0.024390243902439025, 0.4230769230769231, 'buying <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = unacc'),
#  Text(0.012195121951219513, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(0.036585365853658534, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.04878048780487805, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = acc'),
#  Text(0.08536585365853659, 0.5, 'doors <= 2.5\ngini = 0.087\nsamples = 22\nvalue = [0, 1, 21, 0]\nclass = good'),
#  Text(0.07317073170731707, 0.4230769230769231, 'lug_boot <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0]\nclass = good'),
#  Text(0.06097560975609756, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(0.08536585365853659, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = good'),
#  Text(0.0975609756097561, 0.4230769230769231, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0]\nclass = good'),
#  Text(0.16463414634146342, 0.5769230769230769, 'lug_boot <= 1.5\ngini = 0.547\nsamples = 34\nvalue = [2, 0, 14, 18]\nclass = vgood'),
#  Text(0.13414634146341464, 0.5, 'doors <= 2.5\ngini = 0.298\nsamples = 11\nvalue = [2, 0, 9, 0]\nclass = good'),
#  Text(0.12195121951219512, 0.4230769230769231, 'persons <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]\nclass = unacc'),
#  Text(0.10975609756097561, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = good'),
#  Text(0.13414634146341464, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(0.14634146341463414, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]\nclass = good'),
#  Text(0.1951219512195122, 0.5, 'doors <= 2.5\ngini = 0.34\nsamples = 23\nvalue = [0, 0, 5, 18]\nclass = vgood'),
#  Text(0.17073170731707318, 0.4230769230769231, 'lug_boot <= 2.5\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3]\nclass = good'),
#  Text(0.15853658536585366, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = good'),
#  Text(0.18292682926829268, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = vgood'),
#  Text(0.21951219512195122, 0.4230769230769231, 'doors <= 3.5\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 1, 15]\nclass = vgood'),
#  Text(0.2073170731707317, 0.34615384615384615, 'persons <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4]\nclass = vgood'),
#  Text(0.1951219512195122, 0.2692307692307692, 'lug_boot <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]\nclass = good'),
#  Text(0.18292682926829268, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(0.2073170731707317, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = vgood'),
#  Text(0.21951219512195122, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = vgood'),
#  Text(0.23170731707317074, 0.34615384615384615, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = vgood'),
#  Text(0.5274390243902439, 0.6538461538461539, 'maint <= 2.5\ngini = 0.53\nsamples = 199\nvalue = [31, 130, 15, 23]\nclass = acc'),
#  Text(0.39634146341463417, 0.5769230769230769, 'safety <= 2.5\ngini = 0.65\nsamples = 64\nvalue = [4, 32, 15, 13]\nclass = acc'),
#  Text(0.3231707317073171, 0.5, 'buying <= 1.5\ngini = 0.402\nsamples = 39\nvalue = [2, 29, 8, 0]\nclass = acc'),
#  Text(0.2804878048780488, 0.4230769230769231, 'lug_boot <= 1.5\ngini = 0.554\nsamples = 17\nvalue = [1, 8, 8, 0]\nclass = acc'),
#  Text(0.25609756097560976, 0.34615384615384615, 'doors <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7, 0, 0]\nclass = acc'),
#  Text(0.24390243902439024, 0.2692307692307692, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = unacc'),
#  Text(0.23170731707317074, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(0.25609756097560976, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.2682926829268293, 0.2692307692307692, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = acc'),
#  Text(0.3048780487804878, 0.34615384615384615, 'doors <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 8, 0]\nclass = good'),
#  Text(0.2926829268292683, 0.2692307692307692, 'lug_boot <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0]\nclass = good'),
#  Text(0.2804878048780488, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(0.3048780487804878, 0.19230769230769232, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = good'),
#  Text(0.3170731707317073, 0.2692307692307692, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = good'),
#  Text(0.36585365853658536, 0.4230769230769231, 'doors <= 2.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21, 0, 0]\nclass = acc'),
#  Text(0.35365853658536583, 0.34615384615384615, 'lug_boot <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0, 0]\nclass = acc'),
#  Text(0.34146341463414637, 0.2692307692307692, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]\nclass = unacc'),
#  Text(0.32926829268292684, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = acc'),
#  Text(0.35365853658536583, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.36585365853658536, 0.2692307692307692, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(0.3780487804878049, 0.34615384615384615, 'gini = 0.0\nsamples = 16\nvalue = [0, 16, 0, 0]\nclass = acc'),
#  Text(0.4695121951219512, 0.5, 'lug_boot <= 1.5\ngini = 0.63\nsamples = 25\nvalue = [2, 3, 7, 13]\nclass = vgood'),
#  Text(0.4268292682926829, 0.4230769230769231, 'buying <= 1.5\ngini = 0.595\nsamples = 11\nvalue = [2, 3, 6, 0]\nclass = good'),
#  Text(0.4024390243902439, 0.34615384615384615, 'doors <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 6, 0]\nclass = good'),
#  Text(0.3902439024390244, 0.2692307692307692, 'persons <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = unacc'),
#  Text(0.3780487804878049, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(0.4024390243902439, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.4146341463414634, 0.2692307692307692, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = good'),
#  Text(0.45121951219512196, 0.34615384615384615, 'doors <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0, 0]\nclass = acc'),
#  Text(0.43902439024390244, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.4634146341463415, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = acc'),
#  Text(0.5121951219512195, 0.4230769230769231, 'doors <= 2.5\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 1, 13]\nclass = vgood'),
#  Text(0.5, 0.34615384615384615, 'lug_boot <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2]\nclass = vgood'),
#  Text(0.4878048780487805, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = good'),
#  Text(0.5121951219512195, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = vgood'),
#  Text(0.524390243902439, 0.34615384615384615, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = vgood'),
#  Text(0.6585365853658537, 0.5769230769230769, 'lug_boot <= 1.5\ngini = 0.428\nsamples = 135\nvalue = [27, 98, 0, 10]\nclass = acc'),
#  Text(0.5853658536585366, 0.5, 'safety <= 2.5\ngini = 0.492\nsamples = 48\nvalue = [21, 27, 0, 0]\nclass = acc'),
#  Text(0.5609756097560976, 0.4230769230769231, 'maint <= 3.5\ngini = 0.298\nsamples = 22\nvalue = [18, 4, 0, 0]\nclass = unacc'),
#  Text(0.5487804878048781, 0.34615384615384615, 'buying <= 1.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4, 0, 0]\nclass = unacc'),
#  Text(0.5365853658536586, 0.2692307692307692, 'doors <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0]\nclass = acc'),
#  Text(0.524390243902439, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.5487804878048781, 0.19230769230769232, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(0.5609756097560976, 0.2692307692307692, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = unacc'),
#  Text(0.573170731707317, 0.34615384615384615, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = unacc'),
#  Text(0.6097560975609756, 0.4230769230769231, 'doors <= 2.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23, 0, 0]\nclass = acc'),
#  Text(0.5975609756097561, 0.34615384615384615, 'persons <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3, 0, 0]\nclass = unacc'),
#  Text(0.5853658536585366, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = acc'),
#  Text(0.6097560975609756, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(0.6219512195121951, 0.34615384615384615, 'gini = 0.0\nsamples = 20\nvalue = [0, 20, 0, 0]\nclass = acc'),
#  Text(0.7317073170731707, 0.5, 'buying <= 1.5\ngini = 0.316\nsamples = 87\nvalue = [6, 71, 0, 10]\nclass = acc'),
#  Text(0.6829268292682927, 0.4230769230769231, 'maint <= 3.5\ngini = 0.392\nsamples = 43\nvalue = [1, 32, 0, 10]\nclass = acc'),
#  Text(0.6463414634146342, 0.34615384615384615, 'safety <= 2.5\ngini = 0.496\nsamples = 22\nvalue = [0, 12, 0, 10]\nclass = acc'),
#  Text(0.6341463414634146, 0.2692307692307692, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0]\nclass = acc'),
#  Text(0.6585365853658537, 0.2692307692307692, 'lug_boot <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [0, 3, 0, 10]\nclass = vgood'),
#  Text(0.6463414634146342, 0.19230769230769232, 'doors <= 4.0\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 0, 2]\nclass = acc'),
#  Text(0.6341463414634146, 0.11538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = acc'),
#  Text(0.6585365853658537, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = vgood'),
#  Text(0.6707317073170732, 0.19230769230769232, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = vgood'),
#  Text(0.7195121951219512, 0.34615384615384615, 'doors <= 2.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20, 0, 0]\nclass = acc'),
#  Text(0.7073170731707317, 0.2692307692307692, 'safety <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0, 0]\nclass = acc'),
#  Text(0.6951219512195121, 0.19230769230769232, 'lug_boot <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = acc'),
#  Text(0.6829268292682927, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.7073170731707317, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(0.7195121951219512, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(0.7317073170731707, 0.2692307692307692, 'gini = 0.0\nsamples = 16\nvalue = [0, 16, 0, 0]\nclass = acc'),
#  Text(0.7804878048780488, 0.4230769230769231, 'doors <= 3.5\ngini = 0.201\nsamples = 44\nvalue = [5, 39, 0, 0]\nclass = acc'),
#  Text(0.7682926829268293, 0.34615384615384615, 'safety <= 2.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16, 0, 0]\nclass = acc'),
#  Text(0.7560975609756098, 0.2692307692307692, 'lug_boot <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6, 0, 0]\nclass = acc'),
#  Text(0.7439024390243902, 0.19230769230769232, 'doors <= 2.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2, 0, 0]\nclass = unacc'),
#  Text(0.7317073170731707, 0.11538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = unacc'),
#  Text(0.7560975609756098, 0.11538461538461539, 'persons <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = unacc'),
#  Text(0.7439024390243902, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(0.7682926829268293, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(0.7682926829268293, 0.19230769230769232, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(0.7804878048780488, 0.2692307692307692, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = acc'),
#  Text(0.7926829268292683, 0.34615384615384615, 'gini = 0.0\nsamples = 23\nvalue = [0, 23, 0, 0]\nclass = acc'),
#  Text(0.9207317073170732, 0.7307692307692307, 'maint <= 2.5\ngini = 0.496\nsamples = 278\nvalue = [151, 127, 0, 0]\nclass = unacc'),
#  Text(0.8658536585365854, 0.6538461538461539, 'safety <= 2.5\ngini = 0.382\nsamples = 144\nvalue = [37, 107, 0, 0]\nclass = acc'),
#  Text(0.8292682926829268, 0.5769230769230769, 'lug_boot <= 1.5\ngini = 0.5\nsamples = 71\nvalue = [35, 36, 0, 0]\nclass = acc'),
#  Text(0.8170731707317073, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [25, 0, 0, 0]\nclass = unacc'),
#  Text(0.8414634146341463, 0.5, 'doors <= 3.5\ngini = 0.34\nsamples = 46\nvalue = [10, 36, 0, 0]\nclass = acc'),
#  Text(0.8292682926829268, 0.4230769230769231, 'lug_boot <= 2.5\ngini = 0.491\nsamples = 23\nvalue = [10, 13, 0, 0]\nclass = acc'),
#  Text(0.8170731707317073, 0.34615384615384615, 'persons <= 4.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3, 0, 0]\nclass = unacc'),
#  Text(0.8048780487804879, 0.2692307692307692, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = unacc'),
#  Text(0.8292682926829268, 0.2692307692307692, 'doors <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0, 0]\nclass = acc'),
#  Text(0.8170731707317073, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(0.8414634146341463, 0.19230769230769232, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]\nclass = acc'),
#  Text(0.8414634146341463, 0.34615384615384615, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = acc'),
#  Text(0.8536585365853658, 0.4230769230769231, 'gini = 0.0\nsamples = 23\nvalue = [0, 23, 0, 0]\nclass = acc'),
#  Text(0.9024390243902439, 0.5769230769230769, 'doors <= 2.5\ngini = 0.053\nsamples = 73\nvalue = [2, 71, 0, 0]\nclass = acc'),
#  Text(0.8902439024390244, 0.5, 'lug_boot <= 1.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16, 0, 0]\nclass = acc'),
#  Text(0.8780487804878049, 0.4230769230769231, 'persons <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4, 0, 0]\nclass = acc'),
#  Text(0.8658536585365854, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(0.8902439024390244, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(0.9024390243902439, 0.4230769230769231, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0, 0]\nclass = acc'),
#  Text(0.9146341463414634, 0.5, 'gini = 0.0\nsamples = 55\nvalue = [0, 55, 0, 0]\nclass = acc'),
#  Text(0.975609756097561, 0.6538461538461539, 'buying <= 3.5\ngini = 0.254\nsamples = 134\nvalue = [114, 20, 0, 0]\nclass = unacc'),
#  Text(0.9634146341463414, 0.5769230769230769, 'maint <= 3.5\ngini = 0.433\nsamples = 63\nvalue = [43, 20, 0, 0]\nclass = unacc'),
#  Text(0.9512195121951219, 0.5, 'safety <= 2.5\ngini = 0.444\nsamples = 30\nvalue = [10, 20, 0, 0]\nclass = acc'),
#  Text(0.926829268292683, 0.4230769230769231, 'lug_boot <= 2.5\ngini = 0.48\nsamples = 15\nvalue = [9, 6, 0, 0]\nclass = unacc'),
#  Text(0.9146341463414634, 0.34615384615384615, 'doors <= 3.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0, 0]\nclass = unacc'),
#  Text(0.9024390243902439, 0.2692307692307692, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = unacc'),
#  Text(0.926829268292683, 0.2692307692307692, 'lug_boot <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = unacc'),
#  Text(0.9146341463414634, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = unacc'),
#  Text(0.9390243902439024, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(0.9390243902439024, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = acc'),
#  Text(0.975609756097561, 0.4230769230769231, 'doors <= 2.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14, 0, 0]\nclass = acc'),
#  Text(0.9634146341463414, 0.34615384615384615, 'lug_boot <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = acc'),
#  Text(0.9512195121951219, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = unacc'),
#  Text(0.975609756097561, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = acc'),
#  Text(0.9878048780487805, 0.34615384615384615, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0, 0]\nclass = acc'),
#  Text(0.975609756097561, 0.5, 'gini = 0.0\nsamples = 33\nvalue = [33, 0, 0, 0]\nclass = unacc'),
#  Text(0.9878048780487805, 0.5769230769230769, 'gini = 0.0\nsamples = 71\nvalue = [71, 0, 0, 0]\nclass = unacc')]

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(dt_clf, X_test, y_test, display_labels=['unacc', 'acc', 'good', 'vgood'])
# Out:
# /Users/felixschekerka/opt/anaconda3/envs/strive/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
